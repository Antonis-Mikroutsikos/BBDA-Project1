# %%
import pandas as pd
import re

# %%
df = pd.read_csv("v6_Latest_Data_Science_Salaries.csv")
df
# Out:
#                            Job Title Employment Type Experience Level  \
# 0     Business Intelligence Engineer       Full-Time           Senior
# 1     Business Intelligence Engineer       Full-Time           Senior
# 2                        AI Engineer       Full-Time           Senior
# 3                        AI Engineer       Full-Time           Senior
# 4                       Data Analyst       Full-Time           Senior
# ...                              ...             ...              ...
# 4971                  Data Scientist       Full-Time           Senior
# 4972        Principal Data Scientist       Full-Time              Mid
# 4973                  Data Scientist       Full-Time            Entry
# 4974           Business Data Analyst        Contract            Entry
# 4975            Data Science Manager       Full-Time           Senior
#
#      Expertise Level   Salary       Salary Currency Company Location  \
# ...

# %%
df['Job Title'].unique()
# Out:
# array(['Business Intelligence Engineer', 'AI Engineer', 'Data Analyst',
#        'Machine Learning Engineer', 'Data Scientist', 'Insight Analyst',
#        'Data Engineer', 'Data Science Manager', 'Data DevOps Engineer',
#        'Data Architect', 'Machine Learning Researcher',
#        'Analytics Engineer', 'Applied Scientist', 'BI Developer',
#        'Research Scientist', 'Research Analyst', 'Research Engineer',
#        'Data Science Engineer', 'Data Quality Analyst',
#        'Data Product Manager', 'Machine Learning Scientist',
#        'MLOps Engineer', 'Deep Learning Engineer', 'Data Modeler',
#        'Data Product Owner', 'Data Science Consultant',
#        'Business Intelligence Analyst', 'AI Developer', 'Data Manager',
#        'ML Engineer', 'Data Science Director', 'Head of Data',
#        'BI Analyst', 'Data Management Analyst',
#        'Machine Learning Modeler', 'Data Specialist', 'BI Data Analyst',
# ...

# %%
len(df['Job Title'].unique())
# Out:
# 126

# %%
df.groupby('Job Title')['Salary'].count().sort_values(ascending=False).head(20)
# Out:
# Job Title
# Data Engineer                     971
# Data Scientist                    936
# Data Analyst                      662
# Machine Learning Engineer         486
# Analytics Engineer                197
# Research Scientist                152
# Data Architect                    120
# Research Engineer                  93
# ML Engineer                        92
# Data Science Manager               78
# Applied Scientist                  74
# Machine Learning Scientist         59
# Business Intelligence Engineer     55
# Data Manager                       53
# Business Intelligence Analyst      47
# Data Science Consultant            37
# Research Analyst                   36
# AI Engineer                        36
# BI Developer                       29
# Data Specialist                    29
# Name: Salary, dtype: int64

# %%
df['Categorized Job Title']=' '

# %%
for i in range(len(df['Job Title'])):
    j=df['Job Title'][i]
    if j =='Data Engineer':
        df['Categorized Job Title'][i]='Data Engineer'
    elif j =='Data Scientist':
        df['Categorized Job Title'][i]='Data Scientist'
    elif j =='Data Analyst':
        df['Categorized Job Title'][i]='Data Analyst'        
    elif j =='Machine Learning Engineer':
        df['Categorized Job Title'][i]='ML Engineer'  
        
    elif j =='ML Engineer':
        df['Categorized Job Title'][i]='ML Engineer'
        
    elif j =='Data Science Manager':
        df['Categorized Job Title'][i]='Data Scientist'  
        
    elif j =='Applied Scientist':
        df['Categorized Job Title'][i]='Data Scientist'
        
    elif j =='Machine Learning Scientist':
        df['Categorized Job Title'][i]='ML Engineer'
        
    elif j =='Research Scientist':
        df['Categorized Job Title'][i]='Data Scientist'  
        
        
    elif j =='Data Science Consultant':
        df['Categorized Job Title'][i]='Data Scientist'  
        
        
    elif j =='AI Engineer':
        df['Categorized Job Title'][i]='ML Engineer'
    else:
        df['Categorized Job Title'][i]='Other'
        
df
# Out:
# C:\Users\Antonis\AppData\Local\Temp\ipykernel_3640\788729356.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Categorized Job Title'][i]='Other'
# C:\Users\Antonis\AppData\Local\Temp\ipykernel_3640\788729356.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Categorized Job Title'][i]='ML Engineer'
# C:\Users\Antonis\AppData\Local\Temp\ipykernel_3640\788729356.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df.groupby('Categorized Job Title')['Salary'].count().sort_values(ascending=False)
# Out:
# Categorized Job Title
# Other             1393
# Data Scientist    1277
# Data Engineer      971
# ML Engineer        673
# Data Analyst       662
# Name: Salary, dtype: int64
